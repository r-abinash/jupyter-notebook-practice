# %% [markdown]
# # list

# %%
name = 'abinash'

# %%
# print(name)
# Out:
# abinash

# %%
var='1'+'2'

# %%
print(var)
# Out:
# 12

# %%
my=[4,5,1,4]

# %%
print(my)
# Out:
# [4, 5, 1, 4]

# %%
my.append(4)
print(my)
# Out:
# [4, 5, 1, 4, 4]

# %%
my.extend((3,5,0,9))
print(my)
# Out:
# [4, 5, 1, 4, 4, 3, 5, 0, 9]

# %%
my.insert(2,1009)
print(my)
# Out:
# [4, 5, 1009, 1, 4, 4, 3, 5, 0, 9]

# %%
my.pop()
print(my)
# Out:
# [4, 5, 1009, 1, 4, 4, 3, 5, 0]

# %%
my.index(1009)
# Out:
# 2

# %%
my.remove(1009)
print(my)
# Out:
# [4, 5, 1, 4, 4, 3, 5, 0]

# %%
my.count(4)
# Out:
# 3

# %%
my.sort()
print(my)
# Out:
# [0, 1, 3, 4, 4, 4, 5, 5]

# %%
my.reverse()
print(my)
# Out:
# [5, 5, 4, 4, 4, 3, 1, 0]

# %%
my.pop(1)
# Out:
# 5

# %%
my.clear()
print(my)
# Out:
# []

# %%
my = [1,2,[45,3,['hai','o',[9,0]]]]
print(my[2][2][2][0])
# Out:
# 9

# %% [markdown]
# # tuple

# %%
tup = (5,5,5,5,3,(3,4,1,(6,)))
print(tup)
# Out:
# (5, 5, 5, 5, 3, (3, 4, 1, (6,)))

# %%
tup.count(5)
# Out:
# 4

# %%
tup.index(5)
# Out:
# 0

# %%
tup[5][3][0]
# Out:
# 6

# %% [markdown]
# # set

# %%
s = {13,4.2,"hai",13,"hai","h",(2,4,13)}
print(s)
# Out:
# {4.2, (2, 4, 13), 'h', 'hai', 13}

# %%
s.add(4)
print(s)
# Out:
# {4.2, (2, 4, 13), 4, 'h', 'hai', 13}

# %%
s.update({2,3,1,90,45,87})
print(s)
# Out:
# {1, 2, 3, 4.2, 4, 'h', 'hai', 13, 45, (2, 4, 13), 87, 90}

# %%
s.remove('haii')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 s.remove('haii')
#
# KeyError: 'haii'

# %%
s.discard('kai')

# %%
print(s)
# Out:
# {1, 2, 3, 4.2, 4, 'h', 'hai', 13, 45, (2, 4, 13), 87, 90}

# %%
t = {1,23,4,45,'hai'}

# %%
t.union(s)
# Out:
# {(2, 4, 13), 1, 13, 2, 23, 3, 4, 4.2, 45, 87, 90, 'h', 'hai'}

# %%
t.intersection(s)
# Out:
# {1, 4, 45, 'hai'}

# %%
t.issubset(s)
# Out:
# False

# %%
t.issuperset(s)
# Out:
# False

# %%
s.issuperset(t)
# Out:
# False

# %%
s.issubset(t)
# Out:
# False

# %%
s[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 s[1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # dictionary

# %%
d = {
    (1, 2): "tuple key",
    "name": ["Abinash", "Kumar"],
    "marks": {90, 95}
}
print(d)
# Out:
# {(1, 2): 'tuple key', 'name': ['Abinash', 'Kumar'], 'marks': {90, 95}}

# %%
d[(1, 2)]
# Out:
# 'tuple key'

# %%
d['name'][0]
# Out:
# 'Abinash'

# %% [markdown]
# # function

# %%
def multi(par=0):
    '''
        this function 
         multiple
        the parameter
    '''
    print(par*par)

# %%
multi
# Out:
# <function __main__.multi(par=0)>

# %%
def msg(par):
    print(par)

# %%
msg('hello')
# Out:
# hello

# %%
map
# Out:
# map

# %%
#def multi_3(num):return num*3
access = lambda num : num*3

# %%
#multi_3(7)
access(7)
# Out:
# 21

# %%
lst = [1,100,3,9]

# %%
list(map(lambda num:3*num,lst))
# Out:
# [3, 300, 9, 27]

# %%
list(filter(lambda num : num%2==0,lst))
# Out:
# [100]

# %% [markdown]
# # methods

# %%
s = "hai, i am abinash!"

# %%
a=s.rsplit()
print(a)
# Out:
# ['hai,', 'i', 'am', 'abinash!']
